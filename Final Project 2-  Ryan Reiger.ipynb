# %% [markdown]
# ### Project Problem and Hypothesis

# %% [markdown]
# - Identifying data sets that have the ability to predict the movement in asset velocity in an ETF. Use these indicators to rank ETF vs another.
# - ETFs give access to different asset classes (Equities, FI, Commodities) that have their own uniquie liqudity constraints that might cause ETFs to be just as developed but have different Asset Velocities.
# - Asset Velocity is a couninous variable
# - Identifying which factors best predict movement in asset velocity (of a derivative of this value).

# %% [markdown]
# ### Datasets

# %% [markdown]
# - I am getting data directly from Bloomberg, IDC and NYSE.

# %%
from IPython.display import Image
Image(filename = 'Data_Head.png')

# %% [markdown]
# ### Domain knowledge

# %% [markdown]
# - This is a work related project so I have 3 years experience with ETFs and 6 years experience in the Finacial Services Industry
# - Domaine Knowldege is critical for this project.
# - I am not aware of any other research efforts
# - This is a new territory, only have conversations with co workers and my intiution to go off of.

# %% [markdown]
# ### Project Concerns

# %% [markdown]
# - Finance is very data visualization driven. I am concerned I will need to really master MatPlotLib and Seaborn to display the information in a way that makes sense to everyone.
# - I want to quartile rank my funds over specific periods of time, that is goign to be difficult
# - There are 1800 ETFs listed in the US, I am looking at data for 4 of them. My concern is i am looking at the life cycle for to small of a data set.
# - I am also concerned people chose to invest in different product and they are not always logical in their investments. This could skew data.

# %% [markdown]
# ### Outcomes

# %% [markdown]
# - My outcome will be more depending on my ability to visualize the data more than havning a solid model. I work with a bunch of people who are not data scientists.
# - Target Audience wants a visual way of understanding what drives growth in ETFs
# - Model does not have the be complicated, just understandable and palateable.
# - If my project is a bust, then I will use it as a stepping stone to better refine the problem I am trying to solve.
